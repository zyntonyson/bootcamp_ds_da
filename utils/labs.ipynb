# %%
palabra='Roms'
emoji_version=''
for ll in palabra.lower():
    emoji_version+=f' :regional_indicator_{ll}: '

print(emoji_version)
# Out:
#  :regional_indicator_r:  :regional_indicator_o:  :regional_indicator_m:  :regional_indicator_s:
