# %% [markdown]
# # 🛠️ Trabajando con Python y el Entorno de Desarrollo 🐍🚀
#
# ¡Hola! Te damos la bienvenida al segundo webinar del módulo de herramientas de desarrollo. En esta sesión práctica, daremos el salto de trabajar en cuadernos aislados a estructurar un **proyecto real de Python** de manera local en tu computadora.
#
# Aprenderás a estructurar carpetas, gestionar dependencias con entornos virtuales, interactuar con Inteligencia Artificial utilizando prompts profesionales para generar código, y finalmente, crear una **aplicación interactiva web** usando **Streamlit**.
#
# ---
#
# ## 🎯 Objetivos de la Sesión
#
# Al finalizar este webinar, serás capaz de:
# *   **Estructurar proyectos de desarrollo** de forma limpia y profesional.
# *   **Crear y activar entornos virtuales** en Python para el control de dependencias.
# *   **Diseñar prompts efectivos** para automatizar la escritura de scripts y aplicaciones.
# *   **Escribir y ejecutar scripts** de Python desde la terminal.
# *   **Crear e interactuar con Jupyter Notebooks** organizados dentro de un proyecto.
# *   **Construir un panel interactivo (Dashboard)** con Streamlit para la visualización de tus análisis.
#
# ---
#
# ## 📂 1. Estructura de un Proyecto Profesional
#
# Antes de escribir una sola línea de código, necesitamos organizar nuestra área de trabajo. Trabajar de forma profesional requiere estructurar nuestro proyecto para que otros (y nosotros mismos en el futuro) entiendan dónde está cada componente.
#
#
#
# Crea una carpeta raíz en tu computadora llamada `mi-proyecto-datos` y dentro de ella crea la siguiente estructura de archivos y carpetas:
#
# ```text
# mi-proyecto-datos/
# ├── data/              # Archivos de datos (CSV, JSON, datasets, etc.)
# ├── notebooks/         # Cuadernos de Jupyter para análisis exploratorio (EDA)
# ├── prompts/           # Plantillas de texto y prompts enviados a la IA
# ├── scripts/           # Archivos .py de automatización y procesos
# ├── app.py             # Archivo principal de nuestra aplicación Streamlit
# └── requirements.txt   # Listado de librerías necesarias para el proyecto
# ```
#
#
# ### 📂 ¿Qué contendrá cada carpeta?
# *   `prompts/`: Guardaremos plantillas de instrucciones textuales (prompts) que usaremos con la IA para generar código. Esto nos permite documentar cómo generamos nuestro código.
# *   `scripts/`: Guardaremos scripts de automatización de Python (por ejemplo, para generar datos o descargar archivos).
# *   `notebooks/`: Guardaremos los cuadernos de Jupyter para análisis de datos interactivos y visualizaciones rápidas.
# *   `data/`: Para almacenar archivos de entrada y salida (como archivos CSV).
# *   `requirements.txt`: Para registrar todas las librerías externas que instalemos y asegurar la replicabilidad.
# *   `app.py`: El punto de entrada de nuestra aplicación visual e interactiva con Streamlit.
#
# ---
#
# ## 🧰 2. Entorno Virtual: Tu Aislante de Trabajo
#
# Para que nuestro proyecto funcione correctamente y no interfiera con otros programas o proyectos de tu computadora, crearemos un entorno virtual.
#
# ### Paso 1: Crear el entorno
# Ejecuta el siguiente comando en la raíz de tu proyecto para crear la carpeta aislada `.venv`:
#
# ```bash
# python -m virtualenv .venv
# ```
# *(Este comando le pide a Python que use el módulo `virtualenv` para crear una carpeta llamada `.venv` donde se guardará nuestro entorno aislado).*
#
# > 💡 **Nota:** Si la terminal te indica que `virtualenv` no está instalado, puedes instalarlo primero con `pip install virtualenv` o utilizar el módulo integrado de Python ejecutando: `python -m venv .venv`.
#
# ### Activar el entorno virtual ⚡
# Crear el entorno no es suficiente; debemos entrar en él (activarlo). El comando varía según tu sistema operativo:
#
# *   **En Windows (usando GitBash):**
#     ```bash
#     source .venv/Scripts/activate
#     ```
# *   **En macOS y Linux (Terminal):**
#     ```bash
#     source .venv/bin/activate
#     ```
#
# **¿Cómo saber si funcionó?**
# Notarás que al inicio de tu línea de comandos en la terminal aparecerá el nombre del entorno entre paréntesis, por ejemplo:
# `(.venv) usuario@computadora:~$`
#
# Crea el archivo `requirements.txt` en la raíz de tu proyecto e ingresa el siguiente contenido:
#
# ```text
# streamlit
# matplotlib
# seaborn
# pandas
# ipython
# jupyter
# ```
#
# Instala los paquetes en el ambiente virtual
#
# ```bash
#
# # Instalar paquetes desde requirements.txt
# pip install -r requirements.txt
# ```
#
#
# ---
#
# ## 📝 3. Generando Datos con Inteligencia Artificial (Prompts)
#
# Usar Inteligencia Artificial para acelerar tu desarrollo es una habilidad clave. En lugar de escribir un código de simulación desde cero, vamos a diseñar un prompt que le pida a la IA que cree el script por nosotros.
#
# ### 🤖 El Prompt de Generación de Datos
# Crea un archivo llamado `prompts/generar_data.md` y guarda en él la siguiente instrucción para la IA:
#
# ```text
# Genera un conjunto de datos sobre [ventas de una tienda en línea]. Los datos deben:
# 1. Generar [50] filas de datos aleatorios pero consistentes.
# 2. Debe contener columnas numericas, categoricas, booleanas y de fecha.
# 3. Asegurar que los datos sean lógicos y consistentes.
# 4. Los datos deben ser útiles para generar un reporte interactivo tipo dashboard, deben contener algún patrón de interés no mera aleatoriedad
# 5. Presenta los resultados en formato csv separado por comas listo para copiar y pegar
# 6. Agrega suficiente variables para poder hacer graficos de barras, histogramas y scatterplots
# ```
#
# Envía el prompt a la IA de tu elección y salva la salida en `data/datos.csv`

# %% [markdown]
# **Datos de ejemplo** Adopción de animales

# %% [markdown]
# ```csv
# ID_Mascota,Nombre,Tipo_Mascota,Edad_Meses,Tamano,Sexo,Esterilizado,Vacunado,Necesidades_Especiales,Fecha_Ingreso,Fecha_Adopcion,Dias_En_Refugio,Costo_Adopcion_USD
# 1,Max,Perro,8,Mediano,Macho,TRUE,TRUE,FALSE,2025-01-05,2025-01-18,13,150
# 2,Luna,Gato,4,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-01-10,2025-01-20,10,120
# 3,Rocky,Perro,72,Grande,Macho,TRUE,TRUE,FALSE,2025-01-12,2025-04-10,88,50
# 4,Bella,Gato,36,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-01-15,2025-02-28,44,80
# 5,Toby,Perro,3,Pequeño,Macho,FALSE,TRUE,FALSE,2025-01-20,2025-01-26,6,180
# 6,Mimi,Gato,5,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-01-22,2025-02-02,11,130
# 7,Thor,Perro,48,Grande,Macho,TRUE,TRUE,TRUE,2025-01-25,2025-05-15,110,40
# 8,Coco,Conejo,12,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-02-01,2025-02-20,19,60
# 9,Bruno,Perro,10,Grande,Macho,TRUE,TRUE,FALSE,2025-02-03,2025-02-18,15,160
# 10,Nala,Gato,84,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-02-05,2025-05-01,85,45
# 11,Simba,Gato,6,Pequeño,Macho,TRUE,TRUE,FALSE,2025-02-08,2025-02-21,13,125
# 12,Zeus,Perro,96,Grande,Macho,TRUE,TRUE,TRUE,2025-02-10,2025-06-10,120,30
# 13,Daisy,Perro,18,Mediano,Hembra,TRUE,TRUE,FALSE,2025-02-14,2025-03-10,24,110
# 14,Lola,Gato,2,Pequeño,Hembra,FALSE,FALSE,FALSE,2025-02-18,2025-02-23,5,150
# 15,Jack,Perro,60,Mediano,Macho,TRUE,TRUE,FALSE,2025-02-20,2025-04-20,59,60
# 16,Maya,Perro,7,Mediano,Hembra,TRUE,TRUE,FALSE,2025-02-25,2025-03-08,11,155
# 17,Felix,Gato,24,Pequeño,Macho,TRUE,TRUE,FALSE,2025-03-01,2025-03-29,28,90
# 18,Bobi,Perro,108,Pequeño,Macho,TRUE,TRUE,FALSE,2025-03-02,2025-06-15,105,35
# 19,Cleo,Gato,9,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-03-05,2025-03-19,14,120
# 20,Kira,Perro,30,Grande,Hembra,TRUE,TRUE,FALSE,2025-03-08,2025-04-15,38,85
# 21,Lucas,Conejo,18,Pequeño,Macho,TRUE,TRUE,FALSE,2025-03-10,2025-04-05,26,55
# 22,Sasha,Perro,5,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-03-12,2025-03-21,9,170
# 23,Gordo,Gato,60,Pequeño,Macho,TRUE,TRUE,FALSE,2025-03-15,2025-05-10,56,50
# 24,Duke,Perro,14,Grande,Macho,TRUE,TRUE,FALSE,2025-03-18,2025-04-09,22,130
# 25,Chispa,Perro,4,Pequeño,Hembra,FALSE,TRUE,FALSE,2025-03-20,2025-03-27,7,175
# 26,Pelusa,Gato,48,Pequeño,Hembra,TRUE,TRUE,TRUE,2025-03-22,2025-06-20,90,40
# 27,Rex,Perro,84,Grande,Macho,TRUE,TRUE,FALSE,2025-03-25,2025-06-28,95,45
# 28,Milo,Gato,3,Pequeño,Macho,FALSE,TRUE,FALSE,2025-04-01,2025-04-06,5,140
# 29,Frida,Perro,22,Mediano,Hembra,TRUE,TRUE,FALSE,2025-04-02,2025-04-28,26,100
# 30,Oreo,Gato,11,Pequeño,Macho,TRUE,TRUE,FALSE,2025-04-05,2025-04-20,15,115
# 31,Tango,Perro,36,Mediano,Macho,TRUE,TRUE,FALSE,2025-04-08,2025-05-18,40,75
# 32,Molly,Perro,6,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-04-10,2025-04-20,10,165
# 33,Garfield,Gato,72,Pequeño,Macho,TRUE,TRUE,FALSE,2025-04-12,2025-07-01,80,45
# 34,Paco,Ave,24,Pequeño,Macho,FALSE,FALSE,FALSE,2025-04-15,2025-05-01,16,40
# 35,Sombra,Perro,54,Grande,Hembra,TRUE,TRUE,FALSE,2025-04-18,2025-06-12,55,60
# 36,Copito,Conejo,8,Pequeño,Macho,TRUE,TRUE,FALSE,2025-04-20,2025-05-04,14,65
# 37,Chloe,Gato,8,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-04-22,2025-05-03,11,130
# 38,Balto,Perro,120,Grande,Macho,TRUE,TRUE,TRUE,2025-04-25,2025-08-20,117,25
# 39,Salem,Gato,15,Pequeño,Macho,TRUE,TRUE,FALSE,2025-05-01,2025-05-22,21,100
# 40,Lassie,Perro,12,Mediano,Hembra,TRUE,TRUE,FALSE,2025-05-03,2025-05-20,17,140
# 41,Niebla,Gato,30,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-05-05,2025-06-10,36,70
# 42,Bruno,Perro,2,Mediano,Macho,FALSE,FALSE,FALSE,2025-05-08,2025-05-12,4,190
# 43,Pantera,Gato,42,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-05-10,2025-06-25,46,65
# 44,Sam,Perro,66,Grande,Macho,TRUE,TRUE,FALSE,2025-05-12,2025-07-22,71,50
# 45,Kiko,Ave,12,Pequeño,Macho,FALSE,FALSE,FALSE,2025-05-15,2025-06-02,18,35
# 46,Aria,Perro,9,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-05-18,2025-05-30,12,160
# 47,Oliver,Gato,5,Pequeño,Macho,TRUE,TRUE,FALSE,2025-05-20,2025-05-31,11,135
# 48,Kaiser,Perro,78,Grande,Macho,TRUE,TRUE,FALSE,2025-05-22,2025-08-18,88,40
# 49,Nieves,Gato,18,Pequeño,Hembra,TRUE,TRUE,FALSE,2025-05-25,2025-06-18,24,95
# 50,Teddy,Perro,4,Pequeño,Macho,FALSE,TRUE,FALSE,2025-05-28,2025-06-05,8,180
#
# ```

# %% [markdown]
# ## 📊 4. Análisis Exploratorio de Datos (EDA) en un Notebook
#
# Ahora que tenemos los datos simulados, crearemos un cuaderno interactivo para explorarlos de forma rápida.
#
# 1.  Crea un cuaderno de Jupyter llamado `notebooks/EDA.ipynb`.
# 2.  Abre el archivo en VSCode y asegúrate de elegir tu entorno virtual `.venv` en la esquina superior derecha del editor (**Select Kernel**).
# 3.  Agrega y ejecuta los siguientes bloques de código por celdas:
#
# ### Celda 1: Carga de Datos

# %%
import pandas as pd

# Cargar el archivo generado (usando la ruta relativa para salir de 'notebooks/' e ir a 'data/')
df = pd.read_csv("../data/datos.csv")

# Mostrar las primeras 5 filas del conjunto de datos
df.head()

# %% [markdown]
# ### Celda 2: Información General del Dataset

# %%
# Inspeccionar tipos de datos y presencia de valores nulos
df.info()

# %% [markdown]
# ### Celda 3: Resumen Estadístico

# %%
# Obtener resumen estadístico de las variables numéricas
df.describe()

# %% [markdown]
# ---
#
# ## 🎨 5. Creando una Aplicación Interactiva con Streamlit
#
# El paso final es construir una aplicación web interactiva que permita a cualquier usuario explorar nuestros datos visualmente. Usaremos de nuevo la IA para generar el código base.
#
# ### 🤖 El Prompt de Streamlit
# Crea un archivo llamado `prompts/prompt_streamlit.txt` y guarda en él la siguiente instrucción para la IA:
#
# ```text
# Actúa como un desarrollador experto en Streamlit y Python. Escribe el código para app.py que cargue el archivo data/datos.csv. La app debe incluir:
# 1. Un título y un subtítulo llamativo.
# 2. Un checkbox que permita al usuario decidir si desea ver las primeras 5 filas del conjunto de datos en una tabla interactiva.
# 3. Filtros de estilo dropdown y checkbox para dar interactividad.
# 4. Tres gráficos generados con matplotlib o seaborn colocados uno al lado del otro (st.columns):
#    - Un gráfico de barras que muestre las proporciones de una categoria de interés .
#    - Un histograma para la distribución de una variable de interés .
#    - Un  scatterplot entre un par de variables de interés
# 5. El diseño debe lucir profesional, limpio y manejar adecuadamente excepciones si el archivo CSV no existe.
# 6. Usa para los gráficos seaborn
#
# Te comparto una muestra de los datos:
# [Datos muestras]
#
# ```
#
# ### 📄 El Código de la Aplicación: `app.py`
# Envía el prompt a la IA y guarda el código resultante en tu archivo `app.py`. A continuación tienes la implementación interactiva lista para usarse:

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# CONFIGURACIÓN DE LA PÁGINA
# ==========================================
st.set_page_config(
    page_title="Dashboard de Adopción de Mascotas",
    page_icon="🐾",
    layout="wide"
)

# Configuración del estilo global de Seaborn
sns.set_theme(style="whitegrid", palette="viridis")

# ==========================================
# 1. TÍTULO Y SUBTÍTULO LLAMATIVO
# ==========================================
st.title("🐾 Dashboard Interactivo de Adopción de Mascotas")
st.markdown(
    "### *Descubre patrones de permanencia, costos y características clave en el proceso de adopción.*"
)
st.markdown("---")

# ==========================================
# CARGA DE DATOS Y MANEJO DE EXCEPCIONES
# ==========================================
@st.cache_data
def cargar_datos(ruta_csv: str):
    try:
        df = pd.read_csv(ruta_csv)
        # Asegurar tipos de datos booleanos por si vienen como texto
        bool_cols = ["Esterilizado", "Vacunado", "Necesidades_Especiales"]
        for col in bool_cols:
            if col in df.columns and df[col].dtype == 'object':
                df[col] = df[col].astype(str).str.upper() == 'TRUE'
        return df
    except FileNotFoundError:
        return None
    except Exception as e:
        st.error(f"⚠️ Ocurrió un error inesperado al leer el archivo: {e}")
        return None

# Intentar cargar los datos desde la ruta especificada
ruta_archivo = "data/datos.csv"
df = cargar_datos(ruta_archivo)

# Manejo de excepción si el archivo no existe
if df is None:
    st.error(f"❌ **No se encontró el archivo de datos en la ruta:** `{ruta_archivo}`")
    st.info(
        "👉 **Solución:** Crea una carpeta llamada `data/` en el mismo directorio que `app.py` "
        "y guarda allí tu archivo `datos.csv`."
    )
    st.stop()

# ==========================================
# 3. FILTROS EN LA BARRA LATERAL (SIDEBAR)
# ==========================================
st.sidebar.header("🔍 Filtros de Análisis")

# Filtro Dropdown 1: Tipo de Mascota
tipos = ["Todos"] + sorted(list(df["Tipo_Mascota"].unique()))
tipo_sel = st.sidebar.selectbox("Especie de mascota:", tipos)

# Filtro Dropdown 2: Tamaño
tamanos = ["Todos"] + sorted(list(df["Tamano"].unique()))
tamano_sel = st.sidebar.selectbox("Tamaño:", tamanos)

# Filtro Checkbox 1: Necesidades Especiales
solo_especiales = st.sidebar.checkbox("Mostrar solo con necesidades especiales")

# Filtro Checkbox 2: Solo Esterilizados
solo_esterilizados = st.sidebar.checkbox("Mostrar solo esterilizados/as")

# Aplicar lógica de filtrado
df_filtrado = df.copy()

if tipo_sel != "Todos":
    df_filtrado = df_filtrado[df_filtrado["Tipo_Mascota"] == tipo_sel]

if tamano_sel != "Todos":
    df_filtrado = df_filtrado[df_filtrado["Tamano"] == tamano_sel]

if solo_especiales:
    df_filtrado = df_filtrado[df_filtrado["Necesidades_Especiales"] == True]

if solo_esterilizados:
    df_filtrado = df_filtrado[df_filtrado["Esterilizado"] == True]

# ==========================================
# 2. CHECKBOX PARA VISTA PREVIA DE DATOS
# ==========================================
if st.checkbox("👁️ Mostrar las primeras 5 filas del conjunto de datos filtrado"):
    st.subheader("Muestra del Conjunto de Datos")
    st.dataframe(df_filtrado.head(5), use_container_width=True)

st.markdown("---")

# ==========================================
# 4. GRÁFICOS INTERACTIVOS CON SEABORN (3 COLUMNAS)
# ==========================================
if df_filtrado.empty:
    st.warning("⚠️ No se encontraron registros que coincidan con los filtros seleccionados.")
else:
    # Crear tres columnas para colocar los gráficos uno al lado del otro
    col1, col2, col3 = st.columns(3)

    # --------------------------------------
    # GRÁFICO 1: Barras - Proporción por Tamaño
    # --------------------------------------
    with col1:
        st.markdown("##### 📊 Proporción según Tamaño")
        fig1, ax1 = plt.subplots(figsize=(4.5, 3.8))
        
        # Cálculo de proporciones
        proporciones = df_filtrado["Tamano"].value_counts(normalize=True).reset_index()
        proporciones.columns = ["Tamano", "Proporcion"]
        
        sns.barplot(
            data=proporciones,
            x="Tamano",
            y="Proporcion",
            palette="crest",
            ax=ax1
        )
        
        ax1.set_ylabel("Proporción")
        ax1.set_xlabel("Tamaño")
        ax1.set_ylim(0, 1)
        
        # Mostrar porcentaje en las barras
        for p in ax1.patches:
            ax1.annotate(f"{p.get_height():.1%}", 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha='center', va='center', 
                         xytext=(0, 5), textcoords='offset points', fontsize=9)

        plt.tight_layout()
        st.pyplot(fig1)

    # --------------------------------------
    # GRÁFICO 2: Histograma - Días en Refugio
    # --------------------------------------
    with col2:
        st.markdown("##### ⏱️ Distribución de Días en Refugio")
        fig2, ax2 = plt.subplots(figsize=(4.5, 3.8))
        
        sns.histplot(
            data=df_filtrado,
            x="Dias_En_Refugio",
            kde=True,
            color="#2b5c8f",
            bins=10,
            ax=ax2
        )
        
        ax2.set_ylabel("Cantidad de Mascotas")
        ax2.set_xlabel("Días en Refugio")
        plt.tight_layout()
        st.pyplot(fig2)

    # --------------------------------------
    # GRÁFICO 3: Scatterplot - Edad vs. Costo Adopción
    # --------------------------------------
    with col3:
        st.markdown("##### 💵 Edad vs. Costo de Adopción")
        fig3, ax3 = plt.subplots(figsize=(4.5, 3.8))
        
        sns.scatterplot(
            data=df_filtrado,
            x="Edad_Meses",
            y="Costo_Adopcion_USD",
            hue="Tipo_Mascota",
            style="Sexo",
            s=90,
            alpha=0.8,
            ax=ax3
        )
        
        ax3.set_ylabel("Costo Adopción (USD)")
        ax3.set_xlabel("Edad (Meses)")
        ax3.legend(title="Mascota", bbox_to_anchor=(1.02, 1), loc='upper left', frameon=False, fontsize=8)
        plt.tight_layout()
        st.pyplot(fig3)

# %% [markdown]
# ### 🚀 Instalación de Requisitos y Lanzamiento
# Para correr la aplicación web de Streamlit, necesitamos instalar `streamlit`, `matplotlib` y `seaborn` en nuestro entorno virtual activo y ejecutar la app:
#
# ```bash
# # Iniciar la aplicación de Streamlit
# streamlit run app.py
# ```
#
# Streamlit iniciará un servidor local y abrirá automáticamente una pestaña en tu navegador web (usualmente en la dirección `http://localhost:8501`). ¡Interactúa cambiando los filtros de categoría en la barra lateral y observa cómo cambian las métricas y los gráficos en tiempo real! 🤩
#
# ---
#
# ## 🎉 ¡Felicidades, has creado un proyecto completo!
#
# En esta sesión has logrado:
# 1.  **Diseñar la arquitectura física** de tu proyecto.
# 2.  **Gestionar un entorno virtual aislado** para mantener ordenadas tus librerías.
# 3.  **Hacer ingeniería de prompts** sencilla para automatizar código repetitivo.
# 4.  **Desarrollar y probar tus scripts y análisis exploratorios**.
# 5.  **Crear un Dashboard interactivo** en Streamlit listo para mostrar tus descubrimientos de datos.
