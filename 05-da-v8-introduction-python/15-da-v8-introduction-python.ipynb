# %% [markdown]
# # Prepara y estructura datos con Python I 🐍🖥️✍️

# %% [markdown]
# ## Objetivos academicos
# ---

# %% [markdown]
# - 🐍 Entender las bases de Python y el uso de Jupyter Notebook (celdas, ejecución, variables y funciones).
# - 🧠 Aplicar pensamiento analítico y algorítmico; conocer el flujo típico de un análisis de datos.
# - 🐼 Cargar y explorar datos con pandas: `read_csv`, `head()`, `shape`, `columns`, `info()`, `describe()`.
# - 🛠️ Manipular DataFrames y seguir buenas prácticas: renombrar, seleccionar y eliminar columnas (`rename`, selección, `drop`), uso de `inplace`, nombrado y comentarios claros.

# %% [markdown]
# ## Qué es python 🐍 y su uso en análisis de datos
#
# ---

# %% [markdown]
# Python 🐍 es un lenguaje de programación versátil, fácil de aprender y con una sintaxis cercana al lenguaje humano, ideal para quienes inician en análisis de datos. Su fuerza está en su ecosistema de librerías como **NumPy**, **pandas**, **Matplotlib** y **scikit-learn**, que permiten desde limpiar y transformar datos hasta crear visualizaciones y modelos de *machine learning*.
#
# > Piensa en Python como una 🧰 navaja suiza: automatiza tareas, procesa grandes volúmenes de información y convierte datos en conocimiento para la toma de decisiones.

# %% [markdown]
# ## Pensamiento analítico / pensamiento algorítmico 🧠💡
#
# ---

# %% [markdown]
# El **pensamiento analítico** consiste en descomponer un problema en partes más pequeñas para entenderlo y encontrar patrones. En análisis de datos, esto significa observar los datos desde distintas perspectivas, buscar relaciones y proponer hipótesis con base en evidencia.
#
# Por otro lado, el **pensamiento algorítmico** se enfoca en cómo resolver esos problemas paso a paso, mediante instrucciones claras y ordenadas —como si explicaras a una computadora qué hacer. 🧩
#
# > En pocas palabras: el pensamiento analítico te ayuda a **entender el problema**, y el algorítmico a **diseñar la solución**. Juntos son la base para transformar datos en conocimiento accionable.
#
#
#
# ### 🔄 Flujo típico de análisis de datos en Python
#
# 1. **Definición del problema:** comprender qué pregunta queremos responder o qué decisión queremos apoyar.
# 2. **Obtención de datos:** cargar la información desde archivos, bases de datos o APIs.
# 3. **Limpieza y transformación:** tratar valores nulos, corregir errores y preparar los datos para el análisis.
# 4. **Análisis exploratorio (EDA):** usar estadísticas y visualizaciones para descubrir patrones y tendencias.
# 5. **Modelado:** aplicar técnicas estadísticas o de *machine learning* según el objetivo.
# 6. **Interpretación y comunicación:** explicar resultados de forma clara y visual, con foco en la toma de decisiones.
#
# > Este flujo no siempre es lineal: los analistas suelen **volver a pasos anteriores** para mejorar la calidad del análisis y la comprensión del problema.

# %% [markdown]
# ## Entorno de trabajo en Jupyter Notebook 💻✨
# ---

# %% [markdown]
# **Jupyter Notebook** es uno de los entornos más populares para trabajar con Python en análisis de datos. Combina en un mismo espacio **código ejecutable**, **texto explicativo**, **gráficos** y **resultados**, lo que lo convierte en una herramienta ideal para aprender, documentar y compartir proyectos de ciencia de datos.
#
# Cada archivo de notebook tiene extensión `.ipynb` (*Interactive Python Notebook*) y está compuesto por **celdas**, que pueden ser de dos tipos principales:
#
# - 🧮 **Celdas de código:** donde escribes y ejecutas instrucciones en Python.
# - 📝 **Celdas de markdown:** donde puedes incluir texto formateado, ecuaciones o imágenes para documentar tu proceso.
#
# El flujo de trabajo típico es iterativo: ejecutas código, observas resultados, haces ajustes y anotas tus hallazgos directamente en el mismo documento.
# > Piensa en Jupyter como tu **laboratorio interactivo** de análisis: un lugar donde los datos, el razonamiento y los resultados conviven en un solo espacio. 🔍📊

# %% [markdown]
# ### Celdas de texto: *Markdown*

# %% [markdown]
# <center>
#   <img src="https://www.silocreativo.com/wp-content/uploads/2019/05/markdown-cheatsheet.png" alt="Markdown Cheatsheet" style="max-width:50%; height:auto;" width="50%">
# </center>

# %% [markdown]
# ### Celdas de codigo

# %% [markdown]
# En Python, una **variable** es un nombre que usamos para **guardar un valor** (como un número, texto o lista), mientras que una **función** es un conjunto de instrucciones que **realiza una acción** cuando la llamamos.
# Por ejemplo, `edad = 25` guarda un valor, mientras que `print(edad)` ejecuta una acción (mostrar el valor).
# > 📘 En pocas palabras: una variable *almacena información* y una función *hace algo* con esa información.

# %%
#Celda de código <- esto es un comentario

a= 2
b= "Hola"
c= 8

# %%
print(a)
print(a+c)

# %% [markdown]
# ### Consejos para cuando escribas código

# %% [markdown]
# Seguir un estilo coherente al programar mejora la **legibilidad**, la **colaboración** y facilita el **mantenimiento del código**.
# Aquí algunas recomendaciones clave 👇
#
# - 🧩 **Nombrado de variables:** usa nombres descriptivos y en minúsculas, separados por guiones bajos.
#   Ejemplo: `edad_promedio`, `ventas_totales`, `openaq_pm25._clientes`.
#   > Evita nombres genéricos como `data` o `x` si no tienen un propósito claro.
#
#
# - 💬 **Comentarios:** explica *por qué* haces algo, no solo *qué* hace el código.
#   Usa `#` para agregar comentarios breves o `""" ... """` para documentar funciones más largas.
#
#   ```python
#   # Creamos a y b
#   a=5
#   b=6
#   # Calculamos el promedio de los números
#   promedio = (a+b)/2
#   ```
#
#
#
# - ⚙️ **Ejecución en Jupyter:** recuerda que Jupyter mantiene **en memoria todo lo que hayas ejecutado**, por lo que **no necesitas volver a cargar librerías o datasets en cada celda**.
#   > Si reinicias el kernel, sí será necesario volver a ejecutar las celdas previas para restaurar las variables y librerías.
#
#
# > 🧠 Un código limpio no solo funciona bien, sino que también se entiende fácilmente. Escribe pensando en la persona que leerá tu código después (¡aunque seas tú mismo en el futuro!).

# %% [markdown]
# En Jupyter Notebook se recomienda **no abusar del uso de `print()`**, especialmente cuando el objetivo es solo visualizar resultados intermedios.
# Aprovecha el renderizado automático de Jupyter para mostrar **una sola salida por celda**, manteniendo el notebook limpio y legible.
# > ✨ Un notebook bien estructurado combina explicaciones en *markdown* y resultados claros, facilitando la lectura y el análisis paso a paso.

# %% [markdown]
# ### 🧪 Pongamos a prueba lo que hemos aprendido
#
# ¡Hora de practicar lo visto hasta ahora! 🎯
# Sigue estas instrucciones paso a paso en tu notebook y observa cómo Python responde a cada comando 👇
#
# 1. **Crea una variable** llamada `mi_variable`, asígnale un valor (por ejemplo, tu nombre o una frase corta) y muéstrala en otra celda **con y sin `print()`** para ver la diferencia.
# 2. **Crea dos variables numéricas:** una con un número entero (`int`) y otra con un número decimal (`float`).
# 3. **Multiplica ambas variables** y guarda el resultado en una nueva variable llamada `resultado`.
# 4. **Crea una variable de texto**, por ejemplo `"Python Es Genial"`, y aplica el método `.lower()` para convertirla a minúsculas.
# 5. **Guarda el texto en minúsculas** en una nueva variable llamada `texto_minusculas` y muéstrala.
# 6. **Calcula el promedio** de las dos variables numéricas que creaste al inicio y guarda el resultado en una variable llamada `promedio`.
#    Luego, aplica el método `round()` para redondear el valor.
#
# > ✨ *Consejo:* ejecuta cada paso en una celda diferente para ver claramente los resultados de cada operación.

# %% [markdown]
# ## Pandas para análisis de datos 🐼📊
#
# ---

# %% [markdown]
# **pandas** es la librería fundamental de Python para manipular, limpiar y analizar datos estructurados. Su nombre proviene de *Panel Data* y está construida sobre **NumPy**, lo que le da gran velocidad y flexibilidad para trabajar con grandes volúmenes de información.

# %%
#cargando pandas a nuestro ambiente de trabajo. Piensalo es que sacar un cajita de herramientas a donde vas a trabajar
import pandas as pd

# %% [markdown]
# ### 📘 DataFrames
# Un **DataFrame** es una tabla con filas y columnas, similar a una hoja de cálculo de Excel.

# %% [markdown]
# <center>
#   <img src="https://pynative.com/wp-content/uploads/2021/02/dataframe.png" alt="DataFrame" style="max-width:50%; height:auto;" width="25%">
# </center>

# %% [markdown]
# ### 📂 Carga de datos en pandas (DataFrame)

# %%
# Cargar datos desde un archivo CSV
openaq_pm25=pd.read_csv('https://practicum-content.s3.us-west-1.amazonaws.com/datasets/openaq_pm25')

# %% [markdown]
# ### 🔍 Exploración de datos

# %%
# Dimensiones del DataFrame
openaq_pm25.shape

# %%
# Nombres de columnas
openaq_pm25.columns

# %%
# Primeros registros de mis datos
openaq_pm25.head()

# %%
print(openaq_pm25.head())

# %% [markdown]
# En **Jupyter Notebook**, cuando escribes una expresión en la **última línea** de una celda (por ejemplo, `openaq_pm25.head()`), el resultado **se muestra automáticamente** con un formato visual atractivo.
# Esto ocurre porque Jupyter interpreta el valor devuelto por la última instrucción y lo renderiza de manera enriquecida (tablas, gráficos, HTML, etc.).
#
# ```python
# # Muestra una vista previa del DataFrame con formato visual
# openaq_pm25.head()
# ```
#
# En cambio, si usas **`print()`**, el contenido se muestra como texto plano en la consola, sin formato visual ni estilos adicionales:
#
# ```python
# # Muestra el mismo resultado pero sin formato tabular
# print(openaq_pm25.head())
# ```
#
# > 💡 Usa `print()` cuando necesites mostrar múltiples salidas dentro de la misma celda o cuando quieras controlar el formato del texto; pero si solo te interesa ver el resultado, basta con escribir la expresión en la última línea.

# %%
# Información general del DataFrame
openaq_pm25.info()

# %% [markdown]
# En un DataFrame, cada columna tiene un **tipo de dato** (*dtype*) que determina cómo se almacenan y procesan los valores.
# Los más comunes son:
#
# - **int64:** números enteros (por ejemplo, 1, 25, 100).
# - **float64:** números decimales (por ejemplo, 3.14, 250.5).
# - **object:** texto o datos mixtos (strings).
# - **bool:** valores lógicos `True` o `False`.
# - **datetime64:** fechas y tiempos (`YYYY-MM-DD HH:MM:SS`).
# - **category:** variables con categorías fijas, útiles para optimizar memoria.
#
# > 📊 Puedes consultar los tipos de datos de tu DataFrame con `openaq_pm25.dtypes` o convertirlos con `openaq_pm25.astype()`.

# %% [markdown]
# > 🤔 ¿Por qué a veces usamos paréntesis y otras no en pandas?
#
# En Python, hay dos formas comunes de acceder a información o realizar acciones sobre un objeto como un DataFrame.  Por ahora basta con reconocer que los paréntesis indican que estás *ejecutando* una acción sobre/con tu DataFrame.

# %% [markdown]
# ### 📊 Exploración de estadísticas

# %%
# Calcular estadísticas básicas include='all'
openaq_pm25.describe()

# %% [markdown]
# ### 🧩 Manejando datos

# %% [markdown]
# **Renombrar columnas**

# %%
openaq_pm25.rename(columns={"value": "pm25_level"})

# %% [markdown]
# El parámetro **`inplace=True`** indica que la operación debe aplicarse **directamente sobre el DataFrame original**, sin necesidad de reasignarlo a una nueva variable.
# Por ejemplo, al ejecutar `openaq_pm25.dropna(inplace=True)`, las filas con valores nulos se eliminan del propio `openaq_pm25.`.
# Si en cambio usamos `inplace=False` (valor por defecto), la función devuelve una **copia modificada** del DataFrame, dejando el original sin cambios.
# > 💡 Úsalo con cuidado: `inplace=True` ahorra memoria, pero puede dificultar deshacer cambios si necesitas conservar la versión anterior del DataFrame.

# %%
# openaq_pm25.rename(columns={"value": "pm25_level"},inplace=True)
openaq_pm25=openaq_pm25.rename(columns={"value": "pm25_level"})

# %% [markdown]
# **Reordenar o seleccionar columnas**

# %%
openaq_pm25_selection=openaq_pm25[['country_id', 'pm25_level', 'unit']]
openaq_pm25_selection

# %% [markdown]
# **Eliminar columnas**

# %%
openaq_pm25.info()

# %%
openaq_pm25.drop(columns=["unit"], inplace=True) 
openaq_pm25.head()

# %%
openaq_pm25.info()

# %% [markdown]
# ## 🚀 Para seguir aprendiendo :
#
# ---
#
# - 📚 Vuelve a revisar este notebook y trata resolver por tu cuenta  nuevamente
# - 💬 Recuerda que en Discord puedes dejar todos tus comentarios y dudas sobre el contenido del sprint en [`Discord`](https://discord.com/channels/1081207584104656986/1420849538196836472).
#     - 📝 Si tienes preguntas sobre tu proyecto, usa el canal [`#project`](https://discord.com/channels/1081207584104656986/1420848813186351134) para recibir ayuda y compartir ideas.
#     - 🤝 Aprovecha el espacio de `CoLearning` para aclarar tus dudas junto con otros estudiantes e instructores: [Co-Learning](https://discord.com/channels/1081207584104656986/1197953851391746119).
#     - En tus preguntas recuerda etiquetar a `@Dataconsulta` y ubica tu pregunta de acuerdo a `Sprint/Capitulo/Seccion`
# - 📅 ¿Necesitas ayuda personalizada? Puedes agendar una sesión `1:1` conmigo aquí: [1:1 Roman Castillo](https://scheduler.zoom.us/roman-castillo/1-1-roman-castillo).
#
# - Por último hazme paro y responde la encuesta al final de la sesión, me sirve para poder ayudarte mejor
#
# ¡Sigue practicando y no dudes en pedir apoyo cuando lo necesites! 💪✨
