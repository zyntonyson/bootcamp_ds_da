# %% [markdown]
# # **Introducción a base de datos relacionales y consultas SQL**

# %% [markdown]
# ## **Objetivos académicos**
#
# 1. **Comprender los fundamentos de las bases de datos relacionales y el lenguaje SQL**, incluyendo la estructura de tablas, relaciones y la importancia de SQL para la gestión y análisis de datos.
#
# 2. **Desarrollar habilidades prácticas para consultar y manipular datos en SQL**, aplicando comandos como SELECT, WHERE, JOIN, GROUP BY, HAVING, ORDER BY y funciones de agregación para resolver preguntas reales sobre los datos.
#
# 3. **Aplicar técnicas avanzadas de SQL**, como subconsultas, funciones de ventana y manejo de fechas, para realizar análisis más complejos y obtener información valiosa a partir de grandes volúmenes

# %% [markdown]
# ## **🗂️ ¿Qué es una base de datos?**
# Una base de datos es un sistema organizado para almacenar, gestionar y acceder a grandes cantidades de información de forma eficiente. Está diseñada para que los datos puedan ser consultados, modificados y mantenidos con facilidad, ya sea por aplicaciones, usuarios o procesos automatizados. Las bases de datos son fundamentales en casi todos los sistemas digitales, desde redes sociales hasta tiendas en línea.

# %% [markdown]
# ## **🔗 ¿Qué es una base de datos relacional?**
# Una base de datos relacional organiza la información en tablas, donde cada fila representa un registro y cada columna un atributo. Estas tablas se relacionan entre sí mediante claves (primarias y foráneas), lo que permite estructurar los datos y evitar duplicidades. Este modelo facilita consultas complejas, integridad de los datos y escalabilidad, siendo el más utilizado en sistemas empresariales.

# %% [markdown]
# ## **💻 ¿Qué es SQL y por qué es importante?**
# SQL (Structured Query Language) es el lenguaje estándar para interactuar con bases de datos relacionales. Permite consultar, insertar, actualizar y eliminar datos, así como definir estructuras y relaciones. Es una herramienta esencial para analistas, desarrolladores y científicos de datos, ya que brinda el control necesario para explorar, transformar y analizar grandes volúmenes de información de forma precisa y eficiente.

# %% [markdown]
# ## 🧬 Radiografía de una consulta SQL
#
# Una consulta SQL sigue una estructura lógica compuesta por bloques que se ejecutan en un orden específico, aunque no necesariamente en el orden en que los escribimos. Aquí tienes un esquema con los principales componentes:
#
# ```
# SELECT         -- ¿Qué columnas quiero ver?
#   columnas_o_expresiones
# FROM           -- ¿De qué tabla(s)?
#   tabla_base_o_joins
# [WHERE]        -- ¿Qué filas quiero filtrar?
#   condiciones_de_filtro
# [GROUP BY]     -- ¿Cómo agrupo los datos?
#   columna_agrupadora
# [HAVING]       -- ¿Qué grupos cumplen una condición?
#   condiciones_sobre_agregados
# [ORDER BY]     -- ¿En qué orden quiero los resultados?
#   columna [ASC|DESC]
# [LIMIT]        -- ¿Cuántas filas mostrar?
#   número_de_filas
# ```
#
# ---
#
# ### 🔍 Ejemplo comentado
#
# ```sql
# SELECT first_name, last_name, COUNT(*) AS cantidad_rentas  -- Qué columnas mostrar
# FROM customer c                                            -- De qué tabla
# JOIN rental r ON c.customer_id = r.customer_id             -- Unir con tabla relacionada
# WHERE c.active = 1                                         -- Filtrar clientes activos
# GROUP BY c.customer_id                                     -- Agrupar por cliente
# HAVING COUNT(*) > 10                                       -- Solo clientes con más de 10 rentas
# ORDER BY cantidad_rentas DESC                              -- Ordenar por cantidad descendente
# LIMIT 5;                                                   -- Solo los 5 primeros
# ```
#
# ---
#
# ### 🧠 Nota importante
# El orden de ejecución **lógico** en SQL es:
#
# 1. `FROM` (+ `JOIN`)
# 2. `WHERE`
# 3. `GROUP BY`
# 4. `HAVING`
# 5. `SELECT`
# 6. `ORDER BY`
# 7. `LIMIT`
#
# Aunque escribas `SELECT` al inicio, ¡SQL primero arma las tablas y filtra filas antes de mostrar columnas!

# %% [markdown]
# ## 🧪 Consultas a SQL en Sakila
#
# La base de datos Sakila que muestra la operación de una tienda de alquiler de películas, incluyendo tablas para clientes, empleados, inventario, películas, categorías, pagos y alquileres. Es ampliamente utilizada en la enseñanza y práctica de SQL, ya que ofrece un esquema realista, relaciones bien definidas y datos consistentes para realizar consultas complejas y ejercicios de modelado relacional.
#
# Trabajaremos sobre la base de datos `sakila` montada en el entorno. Asegúrate de tener activa tu conexión con SQLite. A continuación, encontrarás una serie de  ejercicios ordenados por nivel de complejidad para practicar distintos aspectos del lenguaje SQL.

# %% [markdown]
# ### Estructura de Sakila

# %% [markdown]
# <center>
#   <img src="https://raw.githubusercontent.com/zyntonyson/dbs_sql/refs/heads/main/er/sakila.png" alt="Sakila ER" style="max-width:50%; height:auto;" width="100%">
# </center>

# %% [markdown]
# > Un diagrama ER (Entidad-Relación) es una representación visual que muestra cómo se relacionan los datos dentro de una base de datos. En él se dibujan entidades (como tablas o elementos principales), sus atributos (las características o columnas) y las relaciones entre ellas. Sirve para planificar y entender la estructura de una base de datos antes de crearla, facilitando el diseño y la comunicación entre desarrolladores y analistas.

# %% [markdown]
# ### Consultas a la base

# %% [markdown]
# #### 0️⃣ Mostrar tablas

# %% [markdown]
# **Consulta:** Muestra las tablas en la base de datos

# %% [markdown]
# ```sql
# SELECT name
# FROM sqlite_master
# WHERE type = 'table'
# ;
# ```

# %% [markdown]
# > Esta sentencia depende la base de dato en la que te encuentres trabajando. Para este ejercicio estamos usando `SQLite`

# %% [markdown]
# #### 1️⃣ Selección básica
# **Consulta:** Muestra el contenido la tabla `film`
#
# ```sql
# SELECT *
# FROM film;
# ```
#
#
# **Pon a prueba tu conocimiento 🤔**
#
# - Muestra todos los registros de la tabla `category`
# - Muestra 10 titulos de la tabla `film`
# - Muestra los primeros 10 actores con su `first_name` y `last_name`.
#
#
#
#
# ---

# %% [markdown]
# #### 2️⃣ Filtrado con condiciones
# **Consulta:** Encuentra todas las películas con una duración mayor a 180 minutos.
#
# ```sql
# SELECT title, length
# FROM film
# WHERE length > 180;
# ```
#
# **Pon a prueba tu conocimiento 🤔**
#
# - Encuentra todos los clientes de la tienda con id = 2 usando la tabla `customers`.
# - Muestra 10 ciudades de la tabla `city` donde el `country_id` sea 82
# - Muestra todas las películas que tienen una descripción registrada
#
#
# ---

# %% [markdown]
# #### 3️⃣ Operadores lógicos
# **Consulta:** Muestra las películas con clasificación 'PG' o 'PG-13'.
#
# ```sql
# SELECT title, rating
# FROM film
# WHERE rating IN ('PG', 'PG-13');
# ```
#
# **Pon a prueba tu conocimiento 🤔**
# - Muestra los actores cuyo apellido sea ‘CHASE’ o ‘DAVIS’ de la tabla `actor`.
# - Encuentra todas las películas que duran más de 100 minutos y tienen clasificación ‘R’ de la tabla `film`.
#
#
# ---

# %% [markdown]
# #### 4️⃣ Ordenamiento
# **Consulta:** Lista los clientes ordenados por `last_name` ascendente y `first_name` descendente.
#
# ```sql
# SELECT first_name, last_name
# FROM customer
# ORDER BY last_name ASC, first_name DESC;
# ```
#
# **Pon a prueba tu conocimiento 🤔**
#
# - **(tabla `film`)**: Muestra las 10 películas más largas, ordenadas por duración descendente.
# - **(tabla `film`)** Muestra los últimos 5 títulos en orden alfabético inverso.
#
#
# ---

# %% [markdown]
# #### 5️⃣ LIKE y patrones
# **Consulta:** Encuentra todas las películas cuyo título comienza con "A".
#
# ```sql
# SELECT title
# FROM film
# WHERE title LIKE 'A%';
# ```
#
# ```sql
# SELECT title
# FROM film
# WHERE title REGEXP '^A';
#
# ```
#
# **Pon a prueba tu conocimiento 🤔**
#
# - Encuentra todas las películas cuyo título comience con la letra **A**.
# - Muestra las películas que contengan la palabra **Love** en su descripción.
# - Lista los actores cuyos apellidos terminen con la letra **S**.
#
# ---

# %% [markdown]
# #### 6️⃣ Agrupación por categoría
# **Consulta:** Cuenta cuántas películas hay por tipo de clasificación (`rating`).
#
# ```sql
# SELECT rating, COUNT(*) AS total
# FROM film
# GROUP BY rating;
# ```
#
#
# **Pon a prueba tu conocimiento 🤔**
#
# - Muestra cuántos clientes existen por store en la tabla `customer`.
# - Muestra la cantidad clientes únicos en la tabla de `payment`
# - Muestra el **monto total (`SUM`) de pagos** realizados por cada cliente en la tabla `payment`.
# - Obtén la **duración máxima (`MAX`)** de las películas por tipo de clasificación (`rating`) en la tabla `film`.
# - Calcula el **promedio (`AVG`)** del monto de pago por empleado en la tabla `payment`.
#
#
#
# ---

# %% [markdown]
# #

# %% [markdown]
# #### 7️⃣ HAVING y filtros de agregados
# **Consulta:** Muestra solo las clasificaciones que tienen más de 200 películas.
#
# ```sql
# SELECT rating, COUNT(*) AS total
# FROM film
# GROUP BY rating
# HAVING total > 200;
# ```
#
#
# - Muestra las ciudades que tienen **más de 5 direcciones registradas** en la tabla `address`.
# - Muestra las categorías que tienen **un promedio (`AVG`) de duración de película mayor a 120 minutos** en la tabla `film`.
#
#
# ---

# %% [markdown]
# #### JOINS

# %% [markdown]
# <center>
#   <img src="https://raw.githubusercontent.com/zyntonyson/img_repo/refs/heads/main/img/sqls.png" alt="Joins Info" style="max-width:100%; height:auto;" width="75%">
# </center>

# %% [markdown]
# ##### 8️⃣ INNER JOIN
#
# Incluye los registros que tienen unicamente coincidencia en ambas tablas unidas
#
# **Consulta:** Muestra los títulos de las películas y los nombres de los actores que actúan en ellas.
#
# ```sql
# SELECT f.title, a.first_name || ' ' || a.last_name AS actor_name
# FROM film f
# JOIN film_actor fa ON f.film_id = fa.film_id
# JOIN actor a ON a.actor_id = fa.actor_id
# LIMIT 10;
# ```

# %% [markdown]
# ##### 9️⃣- 🔟  LEFT/RIGHT JOIN
# **Consulta:** Muestra todos los clientes y sus pagos (si existen).
#
# ```sql
# SELECT c.first_name || ' ' || c.last_name AS cliente, p.amount
# FROM customer c
# LEFT JOIN payment p ON c.customer_id = p.customer_id
# LIMIT 10;
# ```
#
# **🧩 Pon a prueba tu conocimiento 🧠**
#
# - Muestra los nombres de las ciudades junto con los países a los que pertenecen (tablas `city` y `country`).
# - Muestra los nombres de las películas junto con el idioma en que están registradas (tablas `film` y `language`).
#
# ---

# %% [markdown]
# #### 1️⃣1️⃣ Subconsultas
# **Consulta:** Muestra películas más largas que el promedio general de duración.
#
# ```sql
# SELECT title, length
# FROM film
# WHERE length > (
#     SELECT AVG(length) FROM film
# );
# ```
#
# **Consulta:** ¿Cuál es el promedio de duración por clasificación?
#
# ```sql
#
# WITH data AS(
#   SELECT rating, AVG(length) AS avg_length
#   FROM film
#   GROUP BY rating
# )
#
# SELECT rating, avg_length
# FROM data
# ;
# ```
#
#
# **🧩 Pon a prueba tu conocimiento 🧠**
#
# - Muestra los clientes cuyo monto total de pagos sea **mayor que el promedio de pagos de todos los clientes**.
#
# - Calcula el número promedio de películas por categoría utilizando una subconsulta que cuente películas por categoría.
#
# - Obtén el promedio de rentas por cliente usando una subconsulta que agrupe primero las rentas por cliente.
#
#
# ---

# %% [markdown]
# #### 1️⃣2️⃣ Funciones de fecha
# **Consulta:** Cuenta cuántos pagos se realizaron por mes.
#
# ```sql
# SELECT strftime('%Y-%m', payment_date) AS mes, COUNT(*) AS pagos
# FROM payment
# GROUP BY mes
# ORDER BY mes;
# ```
#
#
# **🧩 Pon a prueba tu conocimiento 🧠**
# - Muestra cuántos clientes se registraron por mes usando la tabla `customer`.
#
#
#
#
#
# ---

# %% [markdown]
# #### 1️⃣4️⃣ CASE para categorizar
# **Consulta:** Categoriza las películas según su duración.
#
# ```sql
# SELECT title, length,
#   CASE
#     WHEN length < 60 THEN 'Corta'
#     WHEN length BETWEEN 60 AND 120 THEN 'Media'
#     ELSE 'Larga'
#   END AS categoria
# FROM film
# LIMIT 10;
# ```
#
#
# **🧩 Pon a prueba tu conocimiento 🧠**
#
# - *Categoriza las películas según su duración:*
#   - Menos de 60 minutos → **Corta**
#   - Entre 60 y 120 minutos → **Media**
#   - Más de 120 minutos → **Larga**
#
# - *Clasifica a los clientes según el monto total de sus pagos:*
#   - Menos de 50 → **Bajo**
#   - Entre 50 y 150 → **Medio**
#   - Más de 150 → **Alto**
# ---

# %% [markdown]
# ### 1️⃣5️⃣ Función de ventana: PARTITION BY
# **Consulta:** Muestra el total pagado por cada cliente_id y la suma total por tienda_id.
#
# ```sql
# SELECT DISTINCT c.store_id,  p.customer_id,
#        SUM(amount) OVER (PARTITION BY c.customer_id,store_id) AS total_por_tienda_cliente,
#        SUM(amount) OVER (PARTITION BY store_id) AS total_por_tienda
# FROM customer c
# JOIN payment p ON c.customer_id = p.customer_id
# ```
#
#
# >👉 En resumen:
# `GROUP BY` **colapsa** los datos en grupos.
# `PARTITION BY` **muestra el cálculo por grupo sin perder el detalle fila a fila**.
#
# ---

# %% [markdown]
# ## 🚀 Para seguir aprendiendo :
#
# ---
#
# - 📚 Vuelve a revisar este notebook y trata resolver por tu cuenta  nuevamente
# - 💬 Recuerda que en Discord puedes dejar todos tus comentarios y dudas sobre el contenido del sprint en [`Discord`](https://discord.com/channels/1081207584104656986/1420849538196836472).
#     - 📝 Si tienes preguntas sobre tu proyecto, usa el canal [`#project`](https://discord.com/channels/1081207584104656986/1420848813186351134) para recibir ayuda y compartir ideas.
#     - 🤝 Aprovecha el espacio de `CoLearning` para aclarar tus dudas junto con otros estudiantes e instructores: [Co-Learning](https://discord.com/channels/1081207584104656986/1197953851391746119).
#     - En tus preguntas recuerda etiquetar a `@Dataconsulta` y ubica tu pregunta de acuerdo a `Sprint/Capitulo/Seccion`
# - 📅 ¿Necesitas ayuda personalizada? Puedes agendar una sesión `1:1` conmigo aquí: [1:1 Roman Castillo](https://scheduler.zoom.us/roman-castillo/1-1-roman-castillo).
#
# - Por último hazme paro y responde la encuesta al final de la sesión, me sirve para poder ayudarte mejor
#
# ¡Sigue practicando y no dudes en pedir apoyo cuando lo necesites! 💪✨
