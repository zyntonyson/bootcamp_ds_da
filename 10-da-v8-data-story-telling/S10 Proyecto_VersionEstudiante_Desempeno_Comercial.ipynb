# %% [markdown]
# # Hola! 😀
#
# Soy **Jaime Paz** y mis amigos me suelen llamar James! – *"Tranquilo, no juego en el Real Madrid"* ⚽😅. Sí, como el futbolista James Rodríguez, pero en versión científico de datos… y mejor no me digas como a él. 😉
#
# Como tu revisor en TripleTen, estoy aquí para ayudarte a pulir tu código y tu forma de trabajar con datos. Si algo necesita un ajuste, no te preocupes: la idea es que cada comentario te acerque más a cómo se trabaja en un entorno profesional y que tu proyecto brille con todo su potencial.
#
# Cada vez que encuentre un detalle importante en tu proyecto, te lo señalaré para que puedas corregirlo y seguir creciendo. Si en algún punto no logras resolver algo, también estoy para guiarte en próximos intentos de revisión. 🔁
#
# Es muy importante que, cuando veas mis comentarios, **no los muevas, no los modifiques y no los borres**. Así mantenemos un historial claro de lo que ya revisamos y de tus avances. ✅
#
# ---
#
# ### Formato de Comentarios
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Esta parte está bien implementada y contribuye de forma positiva al análisis o al proyecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Esta parte funciona, pero todavía se puede reforzar para que quede más clara, más completa o más sólida.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - Aquí hay un punto importante por corregir porque afecta la validez del análisis, la implementación o la entrega.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
#
#
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Tu proyecto es excepcional y has logrado cubrir los objetivos del mismo. Abajo he dejado mis comentarios y unas pequeñas recomendaciones para que tomes en cuenta en un futuro y te hagan ¡un máster en Data!
#
# ¡Felicidades!
#
# </div>

# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto.
# Sigue cada paso y espera feedback del evaluador.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop o en Tableau.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 2: Preparación de los datos
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
# - Especifica qué KPIs incluirás y por qué.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
# - Especifica qué filtros o segmentadores usaras.

# %% [markdown]
# ### Diseño y planificación
# ✏️ Describe aquí brevemente tu planificación antes de construir el dashboard.
# - Haz una planeación inicial, después, conforme vayas creando el dashboard, puedes regresar y modificar estas secciones acorde a lo que vayas encontrando.
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# Especifica qué KPIs incluirás y por qué: (3-4 KPIs)
# - Ingresos:
# - crecimiento promedio por año
# - crecimiento total por año
# - crecimiento mensual por año
#
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico tarjeta: Decidi usar la tajeta para mostrar como esta la compañia de modo general.
# - Gráfico de barras: Responde a la pregunta de como ha evolucionado el ingreso total entre 2024 y 2025.
#   Decidi grafico de barras ya que muestra directamente la diferencia entre los dos años.
# - Gráfico de lineas comparación mes/año: Responde a la pregunta como ha evolucionado el ingreso total entre 2024 y 2025 mensualmente.
#    Este grafico permite ver la evolucion de los ingresos a lo largo de los dos años y permite ver patrones estacionales.
# - grafico de barras horizontal: Responde a la pregunta, existen diferencias relevantes entre paises o regiones?    Este grafico permite comparar categorias y ver como se comporta cada una.
# - grafico de barras:Responde a la pregunta que categorias de productos tienen mayor impacto en el negocio?, que segmentos de clientes aportan mayor ingreso y rentabilidad?.
#   Permite ver la diferencia entre categorias de produto y la diferencia en el aporte entre segmentos de clientes en la rentabilidasd y el ingreso.
#
# Descripción de la jerarquía visual:
# - Título: Evolucion de ingresos 2024 vs 2025
#
# Filtro(s)
# - Año
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico comparación segmento de clientes contra ingresos: Gráfico de barras - `Ingresos` vs `segmento de cliente`
# - Gráfico comparación segmento de cliente contra rentabilidad : Gráfico de barras - `rentabilidad` vs `segmento de cliente`
# - Grafico comparacion categoria de producto contra ingresos: grafico barras - 'ingresos' vs 'categoria de producto'
# - Grafico de diferencias entre paises y regiones contra ingresos: grafico de barras acostadas - 'ingresos' vs 'pais' vs 'region'
#
# Filtros
# - `Fecha_pedido`

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# El negocio ha generado ingresos de forma consistente durante los años 2024 y 2025, mostrando un comportamiento relativamente estable y ciclico en el tiempo.
#
# **C (Complicación):**
# se observa una ligera disminución en los ingresos en 2025 frente a 2024, junto con una caída recurrente a mitad de año, esta caida tambien esta presente en el año 2024, lo que podría afectar el rendimiento global del negocio.
#
# **Q (Pregunta):**
# ¿Cuáles son los patrones que explican esta variación en los ingresos y en qué momentos del año existen oportunidades para mejorar el desempeño comercial?
#
# **A (Respuesta):**
#
# El análisis muestra un patrón estacional claro, con disminución de ingresos en mitad de año y recuperación en el último trimestre. Esto sugiere una oportunidad para implementar estrategias comerciales en los meses de menor desempeño y potenciar las campañas en los periodos de mayor demanda.
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# El negocio tiene un desempeño general estable con ingresos a través de distintos segmentos de clientes, categorías de producto y regiones.
# **C (Complicación):**
# Existen diferencias en la contribución de cada segmento, con una alta concentración en el segmento Premium, mientras que otros segmentos aportan significativamente menos como el segmento economico. A pesar de esto, la rentabilidad entre segmentos se mantiene similar.
#
# **Q (Pregunta):**
# ¿Qué factores están impulsando los ingresos del negocio y dónde existen oportunidades para optimizar el crecimiento sin afectar la rentabilidad?
# **A (Respuesta):**
# El análisis muestra que el segmento Premium lidera los ingresos, pero todos los segmentos presentan niveles de rentabilidad similares, lo que indica que el crecimiento depende principalmente del volumen. Además, las categorías de producto tienen una distribución equilibrada y ciertas regiones concentran mayor contribución, lo que sugiere oportunidades de expansión en segmentos de menor volumen sin comprometer la rentabilidad.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# Equipo,
#
# Les comparto dos dashboards que preparé para analizar el desempeño del negocio desde una vista general hasta un nivel más detallado:
#
# 🔹 Overview
# Aquí encontrarán un resumen ejecutivo del comportamiento de los ingresos entre 2024 y 2025, incluyendo la comparación anual y la evolución mensual. Este dashboard permite identificar rápidamente tendencias clave, como la ligera caída en 2025 y un patrón estacional con disminución a mitad de año y recuperación en el último trimestre.
#
# 🔹 Detalle
# En este segundo dashboard podrán profundizar en los drivers del negocio, analizando cómo se distribuyen los ingresos por segmento de cliente, categoría de producto y región. También se incluye la rentabilidad por segmento, lo que permite detectar oportunidades de crecimiento, especialmente en segmentos con menor volumen pero márgenes similares.
#
# Quedo atenta a sus comentarios o preguntas

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **una** de las siguientes opciones, según la herramienta que hayas utilizado:
# - 🔗 Link público del dashboard publicado (Power BI Service o Tableau Public), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %% [markdown]
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
https://public.tableau.com/app/profile/jessica.florez6145/viz/AndesRetailGroup_dashboard/overview?publish=yes

# %% [markdown]
# ## Tabla de evaluación
#
# | Parte | Criterio | Estado | Puntaje obtenido | Puntaje máximo | Comentario breve |
# |---|---|---|---:|---:|---|
# | Parte 1 | Importación del Excel | ✅ Logrado | 5 | 5 | Tu dashboard público carga correctamente y eso permite asumir una conexión funcional al dataset |
# | Parte 2 | Tipos de datos correctos | ✅ Logrado | 5 | 5 | Tu vista publicada usa fechas y montos de forma consistente|
# | Parte 2 | Columna Ganancia |  ✅ Logrado | 5 | 5 | Tu planeación considera rentabilidad y lógica de negocio, pero te recomiendo documentar mejor la fórmula para que esa medida quede totalmente auditable. |
# | Parte 2 | Columna condicional `Nivel de Venta` | ✅ Logrado | 5 | 5 | Defines con claridad la regla de `Nivel de Venta` en la planeación |
# | Parte 3 | Definición de vistas | ✅ Logrado | 4 | 4 | Tú separas bien qué debe responder `Overview` y qué debería responder `Detalle`, y la intención analítica de cada vista queda clara. |
# | Parte 3 | Selección de KPIs | 🟡 Recomendación | 3 | 4 | Priorizas ingresos y variación temporal, pero te faltó justificar mejor por qué otros KPIs del negocio serían clave en la lectura ejecutiva. |
# | Parte 3 | Elección de gráficos | ✅ Logrado | 4 | 4 | Explicas con buena lógica por qué usar líneas, barras y comparaciones categóricas según la pregunta de negocio. |
# | Parte 3 | Jerarquía visual | 🟡 Recomendación | 2 | 3 | Tu intención de lectura es correcta, pero te recomiendo describir con más precisión qué verá primero el usuario antes de entrar al detalle. |
# | Parte 4.1 | KPIs principales | 🟡 Recomendación | 2 | 6 | En la evidencia publicada solo pude validar una tabla resumen de ingreso promedio por año; te faltaron 3 o 4 KPIs principales claramente visibles en la cabecera. |
# | Parte 4.1 | Gráfico de tendencia temporal | ✅ Logrado | 5 | 5 | Muestras la evolución mensual 2024 vs 2025 con un gráfico de líneas y el patrón temporal se entiende rápido. |
# | Parte 4.1 | Comparación geográfica | ❌ No logrado | 0 | 4 | Con lo que entregaste no pude validar una comparación por país o región contra ingresos en barras dentro del `Overview`. |
# | Parte 4.1 | Comparación clientes/productos | ❌ No logrado | 0 | 4 | Con la vista publicada no pude validar una barra por segmento de cliente o categoría de producto dentro del `Overview`. |
# | Parte 4.1 | Gráfico opcional | ✅ Logrado | 2 | 2 | La comparación anual en barras complementa bien la lectura temporal y funciona como apoyo útil dentro de la vista. |
# | Parte 4.1 | Claridad ejecutiva | ✅ Logrado | 4 | 4 | Tu `Overview` se entiende rápido: comparación anual, tendencia mensual y un mensaje principal claro sobre la caída de 2025. |
# | Parte 4.1 | Segmentador opcional | 🟡 Recomendación | 1 | 2 | Incluyes el filtro de `Año`, pero un segundo segmentador útil habría dado más flexibilidad sin sobrecargar la vista. |
# | Parte 4.2 | Gráfico comparación Estación vs Ingresos | ❌ No logrado | 0 | 5 | Con la evidencia disponible no pude validar la vista detallada o bien una comparación de `Estación` vs `Ingresos` en barras. |
# | Parte 4.2 | Comparaciones adicionales | 🟡 Recomendación | 2 | 5 | Tu planeación sí contempla comparaciones por segmento, categoría, país y región, pero no quedaron verificables en la entrega publicada. |
# | Parte 4.2 | Tabla de detalle | 🟡 Recomendación | 1 | 5 | Planteas un análisis más profundo, pero no pude validar una tabla operativa con pedidos, clientes únicos y métricas complementarias. |
# | Parte 4.2 | Segmentación | 🟡 Recomendación | 1 | 5 | Mencionas filtros para la vista detalle, pero con lo que entregaste no pude confirmar al menos dos segmentadores visibles y funcionales allí. |
# | Parte 5.1 | Situation | 🟡 Recomendación | 2 | 3 | Tu dashboard sí comunica el estado general del negocio con la comparación 2024 vs 2025 y el promedio por año, aunque la situación podría ser más completa dentro de la propia vista. |
# | Parte 5.1 | Complication | ✅ Logrado | 2 | 2 | Señalas con claridad la complicación principal: una leve caída en 2025 y una baja a mitad de año. |
# | Parte 5.1 | Question | 🟡 Recomendación | 1 | 2 | La pregunta estratégica está bien pensada en tu narrativa, pero dentro del dashboard no queda tan explícita. |
# | Parte 5.1 | Answer | 🟡 Recomendación | 1 | 3 | Tu vista sugiere el patrón estacional y la recuperación al cierre, pero te faltó convertir ese hallazgo en una respuesta más accionable dentro del dashboard. |
# | Parte 5.2 | Situation | ✅ Logrado | 3 | 3 | Tu narrativa asincrónica resume bien el contexto general del negocio y la evolución de ingresos entre 2024 y 2025. |
# | Parte 5.2 | Complication | ✅ Logrado | 2 | 2 | Explicas de forma clara la caída recurrente a mitad de año y la concentración desigual entre segmentos. |
# | Parte 5.2 | Question | ✅ Logrado | 2 | 2 | Formulas preguntas estratégicas coherentes con los hallazgos y con el objetivo del dashboard. |
# | Parte 5.2 | Answer | ✅ Logrado | 3 | 3 | Tus respuestas proponen acciones razonables para atacar meses débiles y buscar crecimiento sin comprometer rentabilidad. |
#
# ## Subtotal Parte 1
# **5 / 5**
#
# ## Subtotal Parte 2
# **15 / 15**
#
# ## Subtotal Parte 3
# **13 / 15**
#
# ## Subtotal Parte 4.1
# **14 / 25**
#
# ## Subtotal Parte 4.2
# **4 / 20**
#
# ## Subtotal Parte 5.1
# **6 / 10**
#
# ## Subtotal Parte 5.2
# **10 / 10**
#
# ## Total final
# **67 / 100** **APROBADO**
#
# ## Comentario final del revisor
#
# Bien hecho Jessica 🏅. Tu proyecto tiene una base sólida en la parte de planificación y narrativa. Me gustó mucho en particular que hayas definido con claridad qué querías responder con `Overview` y `Detalle`, y también que tu SCQA esté bien estructurado y conectado con decisiones de negocio.
#
# **Tu punto fuerte principal** está en la historia que construyes alrededor de la evolución de ingresos 2024 vs 2025. La vista publicada transmite rápido la caída leve en 2025 y el patrón estacional de mitad de año, y eso le da sentido ejecutivo al dashboard. 💪
#
# **Para subir de nivel** 🚀, te recomiendo concentrarte en dos frentes. Primero, reforzar la evidencia visual del `Overview` con más KPIs y con las comparaciones por geografía y por clientes o productos que pide la rúbrica. Segundo, publicar o dejar verificable la vista `Detalle`, porque ahora mismo ahí se te va una parte importante del puntaje al no poder confirmar gráficos, tabla y segmentadores.
#
# Vas por buen camino, Jessica. Si completas esa segunda vista y alineas mejor los elementos obligatorios de la primera, tu entrega puede quedar mucho más redonda tanto a nivel visual como a nivel de evaluación.
