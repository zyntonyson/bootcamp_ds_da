# %% [markdown]
# # Transformar datos en insights de negocio
#
# ---

# %% [markdown]
# Durante esta sesión cada equipo representará a un grupo de **analistas de datos** asignado a un cliente distinto.  Cada cliente presenta una situación de negocio realista y un conjunto de datos para resolverla.  El objetivo es que los equipos vivan el proceso completo de *data analytics* de principio a fin. 🚀

# %% [markdown]
# ## 🧩 *Objetivo general de la dinámica*
# Aprender a **interpretar las necesidades de un cliente**, trabajar colaborativamente con los datos, y presentar conclusiones útiles que apoyen la toma de decisiones.
#
# Cada equipo deberá:
#
# 1️⃣ Entender el **contexto y objetivos** de su cliente.
# 2️⃣ Formular **preguntas analíticas** alineadas al problema.
# 3️⃣ Realizar **limpieza, exploración y análisis** de los datos.
# 4️⃣ Elaborar **visualizaciones y métricas clave**.
# 5️⃣ Presentar **insights y recomendaciones** al final de la sesión.

# %% [markdown]
# ## Clientes

# %% [markdown]
# 👠 **Academia de baile “Ritmo Vivo”** — *Planeación de próximos cursos*
# > Analizar los datos de sesiones, instructores y cursos para identificar las clases más demandadas, horarios óptimos y oportunidades de expansión.
#
# 🌶️ **Condimentos “Sabor Sureste”** — *Evaluación de expansión de sucursales*
# > Analizar encuestas de intención de compra, competencia local y perfiles de ciudad para identificar las mejores ubicaciones para nuevas sucursales.
#
# 📺 **Empresa de medios “Conecta Media”** — *Alianzas estratégicas con creadores*
# > Explorar datos de campañas, creadores y marcas para descubrir qué colaboraciones generan mejor ROI y afinidad con el público objetivo.
#
# ---

# %% [markdown]
# ### 🩰 Academia de baile “Ritmo Vivo” - Planeación de próximos cursos
#
# ---

# %% [markdown]
# La **Academia Ritmo Vivo** ofrece clases presenciales y virtuales de baile en distintas disciplinas: salsa, bachata, tango, hip-hop y danza contemporánea.
# Durante el último año, la dirección ha notado **fluctuaciones en la asistencia y preferencia por horarios**, además de un **descenso en la inscripción de nuevos alumnos**.
#
# El **stakeholder principal** es *Mariana*, la **Directora Académica**, quien debe planificar el nuevo calendario de cursos para el siguiente trimestre.
# Mariana necesita basar sus decisiones en evidencia y datos del ciclo anterior (enero–junio 2024) para optimizar la oferta.
#
#
#
# #### 🎯 Objetivo del análisis
# Identificar qué cursos y horarios presentan mayor demanda y cuáles podrían ajustarse o reemplazarse en el nuevo trimestre.
#
# #### 💬 Preguntas a responder
#
# 1. “¿Qué estilos de baile tienen mejor demanda?”
# 2. “¿Qué horario es más exitoso?”
# 3. “Los estudiantes están satisfechos con el desempeño de los instructores (Tasa de cancelación)”
# 4. "¿Deberiamos seguir manteniendo la modalidad virtual?
#
#
# #### 📊📈👩‍💻 Reporte interactivo (*dashboard*)
#
# El cliente ha expresado la necesidad de tener un reporte dinámico para monitorear algunas métricas de interés con respecto a los cursos que ofrece. Los requerimientos mínimos para este reporte son:
#
# - El cliente debe poder seleccionar alguno de los ritmos ofrecidos y el dashboard mostrar:
#     - Cantidad de cursos ofertados
#     - Cantidad de estudiantes enrolados
#     - Tasa de asistencia promedio
#     - Tasa de abandono promedio
# - Un gráfico que muestre la cantidad estudiantes que ha tenido cada instructor
# - Un gráfico de barras que muestre el total de cursos ofertados por mes
#
#
# #### 📦 Datos
#
# [Ritmo vivo](https://docs.google.com/spreadsheets/d/1Sy26bw2zMwO9HROozHcB1lOxjleovWIDFzFigWaw6xA/copy)

# %% [markdown]
# ### 🌶️ Condimentos  “Sabor Sureste” — Evaluación de expansión de sucursales
#
# ---

# %% [markdown]
# “Sabor Sureste” es una marca regional de condimentos (mezclas en polvo, salsas y adobos) con operaciones en Yucatán. La dirección busca decidir **en qué ciudades vecinas abrir 1–3 nuevas sucursales** durante el próximo trimestre, priorizando puntos con **alta demanda potencial**, **competencia manejable** y **costos operativos sostenibles**.
#
# #### Stakeholder principal:
# *Laura Hernández — Directora de Expansión.*
#
# #### Objetivo del análisis:
# Estimar la demanda potencial y el tiempo de recuperación por ciudad (break-even), priorizando dónde abrir sucursales físicas y/o fortalecer venta online.
#
# #### 💬 Preguntas / necesidades del stakeholder
# 1. ¿En qué ciudades podemos comenzar a abrir una cartera de clientes?
# 3. ¿Qué ciudades presentan **competencia intensa** (market share y número de tiendas)?
# 4. ¿Qué **canales preferidos** (tienda, marketplace, e-commerce propio) dominan ?
# 5.  ¿Qué tipo de producto nos conviene ofertar en las ciudades seleccionadas?
#
#
#
#
# #### Horizonte temporal:
# Plan de apertura Q1–Q2 2026, con base en datos recopilados en jul–sep 2025.
#
#
#
# #### 📊📈👩‍💻 Reporte interactivo (*dashboard*)
#
# El cliente ha expresado la necesidad de tener un reporte dinámico para monitorear algunas métricas de interés a la encuesta de intención de compra. Los requerimientos mínimos para este reporte son:
#
# - El cliente debe poder seleccionar de las ciudades donde se aplico la encuesta y el dashboard mostrar
#     - Cantidad de personas encuestadas
#     - Frecuencia de compra promedio de los encuestados
#     - Probabilidad de compra promedio de los encuestados
#     - Gasto total promedio de los encuestados
#
# - Un gráfico que muestre la cantidad gastadas por tipo de producto de todos los encuestados
# - Un gráfico por ciudad la conciencia de marca promedio de los encuestados

# %% [markdown]
# #### 📦 Datos
#
# [Sabor Sureste](https://docs.google.com/spreadsheets/d/1Yhqy6j2JaaI7TR9S6ilBosrekPm6dfooPHXmZuzGiVk/copy)

# %% [markdown]
# ### 📺 Empresa de medios “Conecta Media” — Alianzas estratégicas con creadores
#
# ---

# %% [markdown]
# Conecta Media es una empresa de medios digitales que gestiona campañas para marcas en LATAM.
# Para el próximo trimestre desea **priorizar alianzas con creadores de contenido** que maximicen alcance y retorno, asegurando además la **idoneidad para todo público** cuando aplique. Se analizarán datos de:
# 1) **Creadores** (tipo de contenido, aptitud para todo público, audiencia y tarifas),
# 2) **Marcas/Clientes** (industria, producto, público objetivo e importancia estratégica), y
# 3) **Campañas del último trimestre** (jul–sep 2025: costo, impresiones, ingresos, plataforma y creador).
#
# #### Stakeholder principal:
# *Sara López — Directora de Desarrollo de Alianzas.*
#
#
# #### Preguntas/ necesidades del stakeholder:
# 1. ¿Con cuales  creadores  nos conviene mantener alianzas?
# 1. ¿Qué tipo de campaña (*objective*) conviene centrarnos?
# 1. ¿En qué clientes deberiamos enfocarnos?
# 1. ¿Cuál plataforma nos da mejores resultados?
#
#
# #### 📊📈👩‍💻 Reporte interactivo (*dashboard*)
#
# El cliente ha expresado la necesidad de tener un reporte dinámico para monitorear algunas métricas de interés con respecto a las campañas que llevado a cabo. Los requerimientos mínimos para este reporte son:
#     - El cliente debe poder seleccionar la marca con la que ha tenido alguna campaña y el dashboard mostrar
#         - Cantidad de campañas con la marca
#         - Costo total de las campañas que ha tenido con la marca
#         - Ganancias totales de las campañas
#
#
#     - Un gráfico que muestre el costo de campañas por plataforma
#     - Un gráfico por creador las ganancias totales obtenidas

# %% [markdown]
# #### 📦 Datos
#
# [Conecta Media](https://docs.google.com/spreadsheets/d/165ctQWnKR8jIEL2K8VctEzVxSeCd8FTk3Jhfm_2Krjg/copy)

# %% [markdown]
# ## ⏱️ *Estructura del trabajo*

# %% [markdown]
# Cada proyecto seguirá estas etapas guiadas:
#
# 1️⃣ **Organización del equipo (5 min)**
#    - Nombrar roles: responsable, analista visual, encargado de bitácora, expositor.
#    - Asignar el cliente y conjunto de datos.
#
# 2️⃣ **Análisis del contexto y revisión de datos (15 min)**
#    - Leer el caso del cliente.
#    - Revisar los datasets entregados.
#    - Formular preguntas al “stakeholder” para aclarar objetivos.
#
# 3️⃣ **Limpieza, transformación y enriquecimiento (15 min)**
#    - Corregir valores inconsistentes, unificar formatos y realizar joins.
#    - Documentar los cambios en la bitácora.
#
# 4️⃣ **Análisis y descubrimiento de insights (15 min)**
#    - Aplicar tablas dinámicas, gráficos y cálculos de métricas.
#    - Identificar patrones, comparaciones y hallazgos.
#
# 5️⃣ **Preparación de reporte interactivo (20 min)**
#    - Crear una mini dashboard, este debe tener la capacidad de filtrar datos segun la necesidad del cliente.

# %% [markdown]
# ### 🎤 *Cierre de la sesión*
#
# Cada equipo presentará brevemente sus resultados frente al grupo, simulando una reunión de consultoría.
# Los demás equipos podrán hacer *preguntas o comentarios críticos*, reforzando el aprendizaje colectivo.
#
# 💬 *Recuerda:* no hay una única respuesta correcta. Lo más importante es **el proceso analítico**, la claridad de los argumentos y la capacidad de conectar los datos con decisiones reales del negocio.

# %% [markdown]
# ## 🚀 Para seguir aprendiendo :
#
# ---
#
# - 📚 Vuelve a revisar este notebook y trata resolver por tu cuenta  nuevamente
# - 💬 Recuerda que en Discord puedes dejar todos tus comentarios y dudas sobre el contenido del sprint en [`Discord`](https://discord.com/channels/1081207584104656986/1420849538196836472).
#     - 📝 Si tienes preguntas sobre tu proyecto, usa el canal [`#project`](https://discord.com/channels/1081207584104656986/1420848813186351134) para recibir ayuda y compartir ideas.
#     - 🤝 Aprovecha el espacio de `CoLearning` para aclarar tus dudas junto con otros estudiantes e instructores: [Co-Learning](https://discord.com/channels/1081207584104656986/1197953851391746119).
#     - En tus preguntas recuerda etiquetar a `@Dataconsulta` y ubica tu pregunta de acuerdo a `Sprint/Capitulo/Seccion`
# - 📅 ¿Necesitas ayuda personalizada? Puedes agendar una sesión `1:1` conmigo aquí: [1:1 Roman Castillo](https://scheduler.zoom.us/roman-castillo/1-1-roman-castillo).
#
# - Por último hazme paro y responde la encuesta al final de la sesión, me sirve para poder ayudarte mejor
#
# ¡Sigue practicando y no dudes en pedir apoyo cuando lo necesites! 💪✨
