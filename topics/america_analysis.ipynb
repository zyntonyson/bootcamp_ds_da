# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
america_data=pd.read_csv('america.csv')

# %%
america_data
# Out:
#                    pais           capital  poblacion_millones  \
# 0                México  Ciudad de México                 129
# 1        Estados Unidos   Washington D.C.                 334
# 2                Canadá            Ottawa                  39
# 3                Brasil          Brasilia                 203
# 4             Argentina      Buenos Aires                  46
# 5              Colombia            Bogotá                  52
# 6                 Chile          Santiago                  20
# 7                  Perú              Lima                  34
# 8                  Cuba         La Habana                  11
# 9  República Dominicana     Santo Domingo                  11
#
#              idioma             region
# 0           Español  América del Norte
# 1            Inglés  América del Norte
# 2  Inglés / Francés  América del Norte
# 3         Portugués    América del Sur
# 4           Español    América del Sur
# 5           Español    América del Sur
# ...

# %%
america_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pais                10 non-null     object
#  1   capital             10 non-null     object
#  2   poblacion_millones  10 non-null     int64
#  3   idioma              10 non-null     object
#  4   region              10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes

# %%
america_data.groupby('region')['pais'].count()
# Out:
# region
# América del Norte    3
# América del Sur      5
# Caribe               2
# Name: pais, dtype: int64

# %%
america_data.plot(kind='bar',x='pais',y='poblacion_millones')
# Out:
# <Axes: xlabel='pais'>
