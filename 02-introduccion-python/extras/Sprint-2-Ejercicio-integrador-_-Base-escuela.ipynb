# %% [markdown]
# La escuela *Nueva Educación* ha crecido en los últimos años y cuenta con un equipo de  maestros que imparten diversas materias a diferentes grados. La administración busca optimizar la distribución de alumnos por maestro y mejorar la gestión académica.
#
# Como analista de datos, tu tarea es ayudar a la escuela a procesar y analizar la información disponible sobre los maestros.

# %% [markdown]
# ## Descripción de los datos
# Los datos están almacenados en una estructura de listas donde cada maestro tiene la siguiente información:
#
# - **ID**: Identificador numérico único.
# - **Nombre**: Nombre del maestro
# - **Apellido**: Apellido del maestro
# - **Año de ingreso**: Año en que el maestro comenzó a trabajar en la escuela.
# - **Grados asignados**: listado de los grados que el maestro imparte y los alumnos que tiene a cargo en cada grado.
# - **Materias**: Lista de materias que enseña el maestro

# %%
maestros = [
    [1001, " Ana  ", "GÓMEZ", "2010", {"1º": 25, "2º": 30, "3º": 28, "4º": 27}, ["Matemáticas", "Ciencias"]],
    [1002, "luis", "martínez  ", "2005", {"3º": 28, "4º": 35, "5º": 27, "6º": 30}, ["Historia", "Geografía", "Arte"]],
    [1003, "SOFÍA", "ruiz", "2018", {"6º": 20, "1º": 22}, ["Idioma", "Música"]],
    [1004, "  carlos", "FERNÁNDEZ", "2012", {"2º": 22, "3º": 33, "4º": 31, "5º": 30}, ["Ciencias", "Historia", "Matemáticas"]],
    [1005, "elena", "  díaz", "2020", {"1º": 18, "5º": 29, "3º": 20, "6º": 25}, ["Geografía", "Arte"]],
    [1006, "MARÍA", "rodríguez", "2015", {"4º": 31, "5º": 26, "6º": 22}, ["Matemáticas", "Historia"]],
    [1007, "pedro ", "MORALES", "2011", {"2º": 26, "3º": 34, "4º": 23, "5º": 31, "6º": 29}, ["Ciencias", "Idioma", "Música"]],
    [1008, " juan", "ORTEGA  ", "2007", {"5º": 22,  "1º": 30}, ["Historia", "Arte", "Matemáticas"]],
    [1009, "  fernanda", "PÉREZ", "2013", {"1º": 27, "3º": 32, "4º": 25, "5º": 29}, ["Geografía", "Ciencias"]],
    [1010, "daniel  ", "TORRES", "2019", {"4º": 21, "6º": 23, "2º": 28, "5º": 26}, ["Idioma", "Historia", "Música"]],
    [1011, "ISABEL", "  RAMOS", "2006", {"2º": 30, "5º": 31, "3º": 27, "4º": 20}, ["Matemáticas", "Ciencias"]],
    [1012, "emilio", "CRUZ", "2022", {"1º": 20, "2º": 25, "3º": 22, "4º": 29}, ["Historia", "Música"]],
    [1013, "CAROLINA", "soto", "2017", {"4º": 29, "5º": 28, "6º": 27}, ["Geografía", "Arte"]],
    [1014, "miguel", "LOPEZ", "2008", {"3º": 35, "6º": 18, "1º": 26, "5º": 29}, ["Ciencias", "Historia"]],
    [1015, "RAFAEL", "GARCIA", "2014", {"1º": 24, "2º": 33, "3º": 30, "4º": 27, "5º": 22}, ["Matemáticas", "Idioma"]],
    [1016, "monica", "HERNÁNDEZ", "2016", {"5º": 30, "6º": 26, "1º": 19, "2º": 32}, ["Historia", "Arte"]],
    [1017, "ENRIQUE", "cabrera", "2003", {"2º": 19, "4º": 32, "5º": 29, "6º": 25}, ["Matemáticas", "Música"]],
    [1018, "felipe", "  estrada", "2021", {"3º": 29, "5º": 20, "6º": 23, "1º": 31}, ["Ciencias", "Idioma"]],
    [1019, "BEATRIZ", "ruiz", "2010", {"1º": 27, "4º": 34, "5º": 32}, ["Historia", "Arte"]],
    [1020, "jorge", "  montes", "2015", {"6º": 21,  "4º": 28}, ["Matemáticas", "Ciencias"]],
    [1021, "SERGIO", "aguilar", "2009", {"2º": 31, "5º": 19, "1º": 29, "3º": 30}, ["Historia", "Música"]],
    [1022, "claudia", "ORTEGA", "2012", {"3º": 28, "6º": 25, "2º": 24, "5º": 27}, ["Geografía", "Arte"]],
    [1023, "ARTURO", "medina", "2018", {"1º": 26, "4º": 30, "5º": 28, "6º": 22}, ["Matemáticas", "Ciencias"]],
    [1024, "  JULIA", "romero", "2004", {"5º": 22}, ["Historia", "Idioma"]],
    [1025, "mario", "GÓMEZ", "2011", {"3º": 33, "6º": 24, "4º": 30, "5º": 28}, ["Geografía", "Música"]],
    [1026, "Luis", "Castillo", "2025", {}, ["Geografía", "Historia"]],
    [1027, "Jazmin", "Amaya", "2025", {}, ["Matemáticas"]]
]

# %% [markdown]
# Como analista de datos antes comenzar con cualquier análisis es importante que conozcas tus datos.Entonces como primer paso analicemos nuestros datos disponibles
#
#
# ## Objetivos del análisis
#
# - Describe la forma en la que los datos están guardados. Identifica el tipo de dato de cada campo y discute brevemente si consideras que necesitaria alguna modificación
#
# > Tus anotaciones aqui

# %%
# Tu código aquí

# %% [markdown]
# * ¿Para cuántos maestros tenemos datos?

# %%
# Tu código aquí

# %% [markdown]
# * Imprime en pantalla los datos de un maestro

# %%
# Tu código aquí

# %% [markdown]
# * Puedes notar que el nombre de los maestros estan separados en `nombre` y `apellido`, además pareciera que los datos están un poco 'desordenados'. Tratemos de arreglar un poco la situación, escribe una `función` que reciba los datos de uno de los maestros y que devuelva el nombre completo del maestro en formato *Title Case*
#
#
# ````python
#
# def nombre_completo_title(maestro):
#   # Tu código aqui
#
#
# maestro_seleccionado= maestros[0]
#
# nombre_completo_title(maestro_seleccionado)
#
#   >> Ana Gómez
#
# ````

# %%
def nombre_completo_title(maestro):
  # Tu código aqui

# %% [markdown]
# * Ya tenemos una función que nos muestra de forma estilizada el nombre de los profesores. Sería más cómodo si pudieramos tener una función que reciba como argumentos  los datos en `maestros` y `ID` del maestro y nos permitiera saber el nombre del profesor asociado.
#
#
#
# `````python
#
# def obtener_nombre_por_id(datos,id):
#   # tu código aquí
#
#
# # Ejemplos de uso
# obtener_nombre_por_id(maestros,1010)
# >> 'Daniel Torres'
#
# obtener_nombre_por_id(maestros,1020)
# >> 'Sergio Aguilar'
#
# obtener_nombre_por_id(maestros,1030)
# >> 'Maestro no encontrado'
#
#
# `````

# %%
def obtener_nombre_por_id(datos,id):
  # tu código aquí

# %% [markdown]
# Excelente! Es común que tengas que hacer mejoras sobre código que has escrito con anterioridad, este sera nuestro caso
#
# * Básate en la función `obtener_nombre_por_id` y crea una función que además de devolver el nombre del maestro indique la cantidad de grupos que el maestro tiene asignado
#
#
#
#
#
# `````python
#
# def obtener_nombre_y_grupos_por_id(datos,id):
#   # tu código aquí
#
#
# # Ejemplos de uso
# obtener_nombre_y_grupos_por_id(maestros,1010)
# >> 'Daniel Torres tiene 4 grupo(s)'
#
# obtener_nombre_y_grupos_por_id(maestros,1024)
# >> 'Julia Romero tiene 1 grupo(s)'
#
# obtener_nombre_y_grupos_por_id(maestros,1030)
# >> 'Maestro no encontrado'
#
#
# `````

# %%
def obtener_nombre_y_grupos_por_id(datos,id):
  # tu código aquí
