# %% [markdown]
# Hace mucho tiempo, en una galaxia muy, muy lejana... 🌌
#
# La Resistencia ha recuperado archivos antiguos que contienen información sobre personajes icónicos de la saga Star Wars. Sin embargo, los datos están desordenados y requieren limpieza antes de poder ser usados en las nuevas estrategias del consejo Jedi. Tu misión, como aprendiz de programador rebelde, es limpiar estos datos usando tus habilidades con listas anidadas, funciones y métodos de strings.
#
# ¡Que la Fuerza te acompañe! ✨

# %% [markdown]
# Cada personaje está representado como una sublista con los siguientes elementos:
#
# - `character_id`: identificador único del personaje.
# - `name`: nombre con errores como guiones bajos o mayúsculas irregulares.
# - `age`: edad como número decimal.
# - `movies`: lista con títulos de películas desordenados o mal formateados.
# - `roles`: lista de roles importantes como 'JEDI', 'PILOT', 'REBEL'.

# %%
characters = [
    ['001', '  LUKE_skywalker ', 19.0, ['A_NEW_HOPE', 'THE_EMPIRE_STRIKES_BACK'], ['JEDI', 'PILOT']],
    ['002', 'leia organa', 19.0, ['A_NEW_HOPE', 'RETURN OF THE JEDI'], ['REBEL', 'PRINCESS']],
    ['003', '  han-SOLO', 32.0, ['a_new_hope', 'the empire strikes back'], ['PILOT', 'SMUGGLER']],
    ['004', 'OBI_wan KENOBI', 57.0, ['REVENGE_OF_THE_SITH', 'A_NEW_HOPE'], ['JEDI', 'MENTOR']],
    ['005', 'darth_VADER ', 45.0, ['REVENGE_OF_THE_SITH', 'RETURN OF THE JEDI'], ['SITH', 'FATHER']],
    ['006', ' yoda ', 900.0, ['REVENGE_OF_THE_SITH', 'THE_EMPIRE_STRIKES_BACK'], ['JEDI', 'MASTER']],
    ['007', 'PADME_amidala', 27.0, ['ATTACK_OF_THE_CLONES', 'REVENGE_OF_THE_SITH'], ['SENATOR', 'QUEEN']],
    ['008', 'mace-windu', 50.0, ['ATTACK_OF_THE_CLONES', 'REVENGE_OF_THE_SITH'], ['JEDI', 'GENERAL']],
    ['009', 'r2d2', 66.0, ['A_NEW_HOPE', 'RETURN OF THE JEDI'], ['DROID', 'ASTROMECH']],
    ['010', 'c3po', 66.0, ['A_NEW_HOPE', 'ATTACK_OF_THE_CLONES'], ['DROID', 'PROTOCOL']],
    ['011', 'chewbacca', 200.0, ['A_NEW_HOPE', 'THE_FORCE_AWAKENS'], ['SMUGGLER', 'WARRIOR']],
    ['012', 'rey ', 19.0, ['THE_FORCE_AWAKENS', 'THE_LAST_JEDI'], ['JEDI', 'SCAVENGER']],
    ['013', 'finn', 23.0, ['THE_FORCE_AWAKENS', 'THE_LAST_JEDI'], ['REBEL', 'STORMTROOPER']],
    ['014', 'kylo_ren', 29.0, ['THE_FORCE_AWAKENS', 'THE_RISE_OF_SKYWALKER'], ['SITH', 'COMMANDER']],
    ['015', 'poe dameron', 32.0, ['THE_FORCE_AWAKENS', 'THE_LAST_JEDI'], ['PILOT', 'REBEL']],
    ['016', 'bb8', 3.0, ['THE_FORCE_AWAKENS', 'THE_LAST_JEDI'], ['DROID', 'SCOUT']],
    ['017', 'jar_jar binks', 30.0, ['THE_PHANTOM_MENACE'], ['GUNGAN', 'REPRESENTATIVE']],
    ['018', 'qui-gon_jinn', 48.0, ['THE_PHANTOM_MENACE'], ['JEDI', 'MENTOR']],
    ['019', 'general-hux', 35.0, ['THE_FORCE_AWAKENS'], ['FIRST_ORDER', 'COMMANDER']],
    ['020', 'snoke', 100.0, ['THE_FORCE_AWAKENS', 'THE_LAST_JEDI'], ['SITH', 'LEADER']]
]

# %% [markdown]
# # Paso 1: Limpieza individual de datos
#
# Crea una función llamada `clean_character` que reciba la lista de un personaje, el índice del nombre y el índice de la edad. Esta función debe:
#
# 1. Eliminar espacios y guiones bajos del nombre, y aplicar formato de título (inicial mayúscula).
# 2. Convertir la edad a entero.
# 3. Devolver la lista del personaje con los datos limpios.

# %%
# Escribe tu función aquí
def clean_character(character, name_index, age_index):


# Prueba la función
QuiGonJinn = ['018', 'qui-gon_jinn', 48.0, ['THE_PHANTOM_MENACE'], ['JEDI', 'MENTOR']]
print(clean_character(QuiGonJinn, 1, 2))

# %% [markdown]
# # Paso 2: Limpieza de películas
#
# Crea una lista llamada `cleaned_movies` donde cada entrada sea una sublista con los títulos de las películas en formato limpio (sin guiones bajos, con cada palabra capitalizada).

# %%
cleaned_movies = []

# Tu código aqui

print(cleaned_movies)

# %% [markdown]
# # Paso 3: Contar personajes por rol
#
# Escribe una función `count_by_role(characters, role)` que reciba la lista y un rol, y devuelva cuántos personajes tienen ese rol.

# %%
def count_by_role(characters, role):


print("Número de JEDI:", count_by_role(characters, 'jedi'))

# %% [markdown]
# # Paso 4: Diccionario de roles
#
# La resistencia necesita una forma rápida de identificar a todos los personajes con un rol específico.
#
# Tu misión ahora es transformar los datos en una estructura que permita agrupar a los personajes por su rol principal. Para ello:
#
# * Escribe una función llamada `group_characters_by_role` que reciba como entrada una lista de personajes.
# * La función debe devolver un diccionario donde:
#   * Cada llave es un rol único (por ejemplo `'JEDI'`, `'PILOT'`, `'SITH'`, etc.)
#   * Cada valor es una lista con los nombres **limpios** de los personajes que tienen ese rol.
#
# 🎯 *Importante*: usa el mismo formato de nombre limpio que generaste con `clean_character`.
#
# 👉 Puedes asumir que ya se limpió previamente el campo del nombre (es decir, que no necesitas hacer limpieza dentro de esta función).
#
# Salida esperada:
#
# ```
# {
#   'JEDI': ['Luke Skywalker', 'Obi Wan Kenobi', 'Yoda', 'Mace Windu', 'Rey', 'Qui Gon Jinn'],
#   'PILOT': ['Luke Skywalker', 'Han Solo', 'Poe Dameron'],
#   'SITH': ['Darth Vader', 'Kylo Ren', 'Snoke'],
#   'DROID': ['r2d2', 'c3po', 'bb8'],
#   ...
# }
# ```

# %%
def group_characters_by_role(characters):
  # Tu codigo acá
